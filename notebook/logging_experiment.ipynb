# %%
print("hi")
# Out:
# hi

# %%
# python logging module
# structlog (output format)

import os
import logging
from datetime import datetime

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\Shiva\\RAG_Project\\document_chat\\notebook'

# %%
os.path.join(os.getcwd(),"logs")
# Out:
# 'c:\\Users\\Admin\\Shiva\\RAG_Project\\document_chat\\notebook\\logs'

# %%
os.makedirs(os.path.join(os.getcwd(),"logs"))

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 4, 21, 20, 22, 14, 314423)

# %%
#21_o4_2026.log
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y')}.log"
print(LOG_FILE)
# Out:
# 04_21_2026.log

# %%
LoG_Folder=os.path.join(os.getcwd(),"logs")
LOG_FILE_PATH=os.path.join(LoG_Folder,LOG_FILE)
print(LOG_FILE_PATH)
# Out:
# c:\Users\Admin\Shiva\RAG_Project\document_chat\notebook\logs\04_21_2026.log

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
 logging.basicConfig(
            filename="self.LOG_FILE_PATH",
            format="%(message)s",
            handlers=[file_handler,console_handler]
        )

# %%
logger = logging.getLogger(__name__)
logger.info("i set up python logging")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
logger.error("i set up python logging")
